# %% [markdown]
# # All in One
#
#   - 1 Quantification
#
#       - General UV Absorbance
#
#         - Major
#           - Try (Trp)
#           - Tyr
#         - Minor
#           - Cys (–S-S-)
#
#
#         - Easy
#         - Sample Recoverable
#         - Interference
#           - Chromophores
#           - Nucleic acids
#
#       - Far UV Absorbance
#
#         - 190 nm
#
#         - Advantages
#           - Detect from peptide bonds
#
#         - Disadvantages
#           - Interference at 190 nm
#             - O2
#           - Interference at 205 nm
#             - buffer
#             - heme
#             - pyridoxal group
#           - Low sensitivity (205 nm → 190 nm)
#           - Calibration Requirement
#
#       - Near UV Absorbance
#
#         - 280 nm
#
#         - Major
#           - Try (Trp)
#             - 5690
#           - Tyr
#             - 1280
#         - Minor
#           - Cys
#             - 120
#
#         - A₂₈₀ (1mg/ml) = (5690 Trp + 1280 Tyr + 120 Cys) / M
#
#         - Reliable and Easy
#         - No Buffer Absorption
#         - Correction for Nucleic Acids
#           - Protein (mg/ml) =
#           - 1.55
#           - × A₂₈₀
#           - (- 0.76)
#           - × A₂₆₀
#
#       - Lowry Method
#
#         - Based on 2 reactions
#
#           - Biuret Reaction
#             - Cu²⁺ +
#             - peptide bonds +
#             - alkaline conditions →
#             - Biuret chromophore
#
#           - Folin-Ciocalteu Reaction
#             - Tyr, Try (Trp) +
#             - phosphomolybdate (H₃PMo₁₂O₄₀) +
#             - phosphotungstate (H₃PW₁₂O₄₀) →
#             - Heteropolymolybdenum blue
#
#         - Strong Blue color
#           - Detectable within 500-750 nm
#           - Commonly chosen for measurement
#             - 660 nm
#             - 750 nm
#
#         - Advantages
#           - High Sensitivity
#             - 100-Fold than Biuret
#             - 0.01 mg/ml
#           - Strong Color Development
#           - Wider Wavelength Range
#             - 500-750 nm
#
#         - Disadvantages
#           - Bind preference
#             - Tyr
#             - Try (Trp)
#           - Interference
#             - Red
#           - Complexity
#
#       - BCA assay
#         - Bicinchoninic Acid
#         - Similar to Lowry method
#         - Cu(II→I) under HO-
#         - Cu(I) + BCA = purple-colored complex
#         - 562 nm
#
#         - Advantages
#           - One-Step Process (Lowry two-step)
#           - Sensitivity ＞ Lowry method
#           - Suitable for low protein concentrations
#
#         - Disadvantages
#           - Cu(I) amount affect by
#             - protein concentration
#             - incubation time
#           - Requiring precise control
#
#       - Bradford method
#         - Coomassie Blue G250 dye
#         - Free dye in 3 ionic forms
#           - Cationic
#             - orange-red
#             - 470 nm
#           - Anionic
#             - blue
#             - bind to proteins
#             - 590 nm
#
#         - 2 absorption spectra Overlap
#           - Non-linear standard curve
#
#         - Simple and quick assay
#
#         - Bind preference
#           - Arg
#           - Lys
#
#   - 2 Electrophoresis
#
#     - Polyacrylamide Gels
#
#       - Polymerisation
#
#         - Acrylamide
#           - CH2=CHCONH2
#
#         - N,N’-methylene-bisacrylamide
#           - CH2(NHCOCH=CH2)2
#
#       - Radical generation catalysis
#
#         - APS
#           - ammonium persulfate
#         - TEMED
#           - N,N,N’,N’-tetramethylenediamine
#
#     - SDS-PAGE
#
#       - Stacking gel
#
#         - Short gel on top
#         - Sample Stacking
#         - Low conc. acrylamide
#         - Low ionic strength
#         - Large pore
#         - pH
#           - 6.9
#         - Charge carrier
#           - Cl-
#         - glycine form
#           - Zwitterion
#
#       - Resolving gel
#         - pH
#           - 8-9
#         - glycine form
#           - Anion
#         - Charge carrier
#         - glycinate ions
#
#         - Tris glycine pH
#           - 8-9
#
#       - Denaturing
#         - SDS
#           - Anionic detergent
#         - β-mercaptoethanol
#           - reduces disulfide bridges
#
#       - Migration
#         - size
#
#     - Native PAGE
#
#       - Preserving
#         - tertiary structures
#         - quaternary structures
#       - Enables study
#         - subunits interactions
#         - different modifications
#       - Migration dependent on
#         - size
#         - shape
#         - charge
#       - Applications
#         - Apoferritin
#           - 24 subunits
#           - Self-assemble → protein nanocage
#             - different ratios
#               - modified apoferritin
#                 - Z_HER2-Apoferritin
#                 - 27 kDa
#               - unmodified apoferritin
#                 - Apoferritin
#                 - 22 kDa
#
#     - Gradient SDS-PAGE
#
#       - Acrylamide conc. ↑
#       - Pore size ↓
#       - Wide protein MW
#       - Higher resolution
#       - Complicated to Set Up
#
#     - IEF
#       - Isoelectric Focusing
#       - Low% polyacrylamide
#       - Ampholytes
#       - Electric field induces →
#         - pH gradient
#       - Proteins stop at pI
#
#     - 2D Electrophoresis
#       - 1st Dimension
#         - pI
#       - 2nd Dimension
#         - size
#
#       - Proteomics
#
#         - Define Biological Question
#         - Conduct Sample Preparation
#         - Perform 2-D Gel Electrophoresis
#         - Capture results through Imaging
#         - Extract proteins from gel
#         - Protein Digestion for analysis
#         - MS: Determine protein identity
#         - Global Bioinformatics Analysis
#
#   - 6 Yeast two/three-Hybrid
#
#     - Native yeast GAL4 protein
#
#       - transcriptional activator
#
#       - DNA-Binding domain (DB)
#         - aa 1-147
#         - bind UAS
#
#       - Activation Domain (AD)
#         - aa 768-881
#         - directs RNA pol. II
#         - transcribe gene downstream UAS
#
#     - Selection Reporter
#       - lacZ
#         - β-galactosidase
#       - Nutritional marker
#         - adenine
#         - histidine
#         - in media lacking adenine / histidine
#       - other reporter systems
#
#     - Advantages
#       - In vivo interaction
#       - Detect transient interaction
#       - identify single aa in interaction
#       - identify new protein interactant
#
#     - Disadvantages
#       - Difficult and time consuming
#       - Many false +ve
#       - Yeast grow slowly
#
#     - three-Hybrid
#
#   - 14 PTM
#
#     - Phosphorylation
#       - HO-
#         - by kinase
#         - covalently addition
#         - reversible by phosphatases
#       - change protein interactions
#       - control protein across membranes
#       - Abnormal phosphorylation
#         - cancer
#         - degenerative disorders
#
#     - Glycosylation
#       - + Carbohydrates → glycoprotein
#       - N-Glycans linked
#         - Asn
#       - O-Glycans linked
#         - Ser
#         - Thr
#       - Essential in protein folding
#       - Major role
#         - cell–cell recognition
#         - signalling
#
#   - 15 Role Protein
#
#     - Actin
#       - Structural proteins
#       - Most abundant protein
#       - Main component of cytoskeleton
#       - 42 kDa
#       - Globular protein
#       - Forms fibrils throughout cell
#
#     - Ferritin
#       - Mineral storage
#       - Function for Fe
#         - oxidise
#         - incorporate
#         - keeps in non-toxic form
#       - 24-mer structure
#         - large cavity
#           - iron storage
#         - separated from solution
#           - by 2 nm protein shell
#
#     - Ion channels
#       - Membrane transport
#       - Integral membrane protein
#       - Circular arrangement
#         - packed around waterfilled pore
#         - location
#           - membrane
#           - lipid bilayer
#
#
#
# # 100 E. coli Strains
#
#   - BL21
#     - deficient in lon and ompT proteases
#       - avoid excessive protein degradation
#
#   - BLR
#     - recA- 重组酶A缺失
#       - ↑ plasmid monomer yields
#       - Stabilize repetitive sequence plasmids
#
#   - B834
#     - Methionine auxotroph 甲硫氨酸缺陷型菌株
#       - labels S35/Se for crystallography
#
#   - AD494
#     - Thioredoxin reductase deficient (trxB-) 硫氧还蛋白还原酶缺失型
#       - Aid disulfidebond formation
#
#   - Rosetta strains
#     - express rare codons proteins
#
#   - MCS
#     - Multiple Cloning Site
#     - insert gene through multiple restriction sites
#
# # 200 Thermostable DNA polymerase
#
#   - Automation
#   - Accuracy
#   - Processivity
#   - Stability
#
#   - e.g.
#
#     - Taq Polymerase
#       - Thermus aquaticus
#       - High processivity
#       - Lower fidelity (no 3’-5’ exonuclease)
#       - Activity lost
#         - 50%
#         - 30 min
#         - 95°C
#       - Add an extra A base at 3’-end
#
#     - Vent Polymerase
#       - Thermococcus litoralis
#       - Lower processivity than Taq
#       - Higher fidelity (3’-5’ exonuclease)
#       - Activity lost
#         - 10%
#         - 60 min
#         - 98°C
#       - Forms blunt-ended
#
#     - Deep Vent Polymerase
#       - Pyrococcus
#       - Lower processivity than Taq
#       - Higher fidelity (3’-5’ exonuclease)
#       - Extremely stable at high temperatures
#       - Grows at
#         - 2000 metres
#         - 104°C
#
#     - Therminator DNA Polymerase
#       - Thermococcus
#       - Grows at
#         - 2500 metres
#       - Activity lost
#         - 50%
#         - 6.7 h
#         - 95°C
#
#     - KOD DNA Polymerase
#       - Thermococcus kodakaraensis
#       - Higher fidelity (3’-5’ exonuclease)
#       - High processivity
#         - Twice of Taq
#
#
#
#
#
# # 3 Molecular Biology basics
#
#   - Cloning techniques
#
#     - Plasmids
#       - Circular
#       - extra-chromosomal
#       - Replicate independently of chromosomal DNA
#       - Plasmids Occurrence
#         - bacteria
#         - archaea
#         - some eukaryotes
#       - Carry antibiotic resistance
#       - Use in Cloning
#         - "vector"
#         - Antibiotic Resistance Gene → selection
#         - MCS
#
#     - Restriction Enzymes
#       - active site
#         - Mg2+
#       - Cut DNA specifically
#         - Bgl11
#           - A↓GATCT
#         - AluI
#           - AG↓CT
#         - BamHI
#           - G↓GATCC
#         - BfaI
#           - C↓TAG
#         - DpnII
#           - ↓GATC
#         - EcoRI
#           - G↓AATTC
#         - HaeIII
#           - GG↓CC
#         - HindIII
#           - A↓AGCTT
#         - NotI
#           - GC↓GGCCGC
#         - NruI
#           - TCG↓CGA
#         - RsaI
#           - GT↓AC
#         - SacI
#           - GAGCT↓C
#         - SmaI
#           - CCC↓GGG
#         - Tru9I
#           - T↓TAA
#         - PstI
#           - CTGCA↓G
#       - sticky ends
#
#     - DNA Ligases
#       - active site
#         - Lys
#       - make new phosphate bond
#       - 2 ATP phosphate bonds hydrolysis
#
#
#   - PCR
#
#     - Copying Interest Gene
#
#       - Start/Stop define target DNA
#       - Gene copied through repeated cycles
#         - DNA Melting
#         - Primer Annealing
#         - Extension
#
#     - PCR Cloning
#       - Primers add restriction sites
#       - Sequencing ensures accuracy
#
#   - pET-based expression in E. coli
#
#     - pET System
#       - Prokaryotic Expression
#       - Control Mechanism
#         - Genes under T7 promoter
#         - T7 RNA polymerase initiates expression
#
#       - T7 RNA Polymerase
#         - provided by prophage
#           - λDE3 lysogen
#         - LacI-lacO blockade
#         - IPTG binds lacI, removes inhibition
#         - IPTG
#
#   - Tagging
#
#     - Tags
#       - Peptides added (fused)
#         - N-terminal
#         - C-terminal
#       - aid, at genetic level
#         - isolation
#         - purification
#         - solubility
#
#     - Tags can impact
#       - protein folding
#       - biological activity
#       - crystallization
#       - use with care
#
#     - His
#
#       - IMAC
#         - Immobilised Metal Affinity Chromatography
#         - Metals used in IMAC
#           - Ni2+
#           - Co2+
#           - Cu2+
#           - Zn2+
#
#       - Hexahistidine
#         - His₆
#
#     - MBP
#
#       - pMAL fusion system
#         - Protein Maltose-Binding Protein Fusion
#       - Gene inserted downstrem of malE
#       - Fusion with MBP
#       - MBP, protease cleavage
#         - site between
#           - malE and
#           - inserted gene
#         - e.g. protease
#           - factor Xa
#           - enerokinase
#           - genenase I
#       - solubility ↑
#         - insoluble proteins
#
#       - Paramyosin 肌肉蛋白
#
# # 4 Protein Purification
#
#   - Protein chromatography
#
#     - Different partitioning of proteins between
#       - stationary phase
#         - adsorbent
#       - mobile phase
#         - Buffer solution
#         - Composition change
#           - control protein binding/elution
#
#     - Specificity
#       - altered by adsorbent
#       - efficiency
#       - selectivity
#
#     - Adsorbent
#       - 90% solvent
#       - 10% porous matrix
#
#     - Matrix
#       - hydrophilic
#       - chemically & physically stable
#       - no functional groups → indiscriminate protein binding
#       - controllable porosity, rigid to allow good flow rates
#
#     - Protein separation
#       - size
#       - shape
#       - net charge
#       - hydrophobicity
#         - HIC
#       - thiol function
#         - Covalent Chromatography
#       - substrate binding
#         - Biospecific Affinity Chromatography
#
#   - Size Exclusion Chromatography
#
#     - Gel filtration
#
#     - Protein MW determine by
#       - shape
#         - globular (round) ＞ rod-like
#
#       - size
#         - Small ＞ Large
#
#   - Ion Exchange Chromatography
#
#     - Most widely used
#
#     - Ion Exchange principle
#
#       - competition
#         - charged protein
#         - competing ion
#       - oppositely charged column
#
#       - bind to column
#         - concentration of competing ions ＜ protein
#
#       - elute from column
#         - ionic strength increased
#         - competing ions remove the protein
#
#     - Q Sepharose
#       - Quaternary Ammonium
#       - Anion exchanger
#       - binds –vely charged protein
#
#     - S Sepharose
#       - Sulfonic ions
#       - Cation exchanger
#       - binds +vely charged protein
#
#     - protein at pI
#       - fully ionised
#       - no net charge
#
#     - buffer pH
#       - affect protein charge
#       - make protein bind to Q/S column
#
#   - HIC
#
#     - Hydrophobic Interaction Chromatography
#
#     - Hydrophobic molecules
#       - self-associate in aq.
#
#     - Hydrophobic residues
#       - hidden inside protein
#       - some exposed on surface
#         - bind to adsorbent hydrophobic ligand
#
#     - Adsorption to Hydrophobic ligand
#       - favoured at high ionic strength
#         - Anti-chaotropic salts
#           - SO42-
#           - Cl-
#           - enhance hydrophobic interaction
#
#     - Elution achieved by
#       - ↓ salt conc.
#       - ↓ ionic strength
#
#     - e.g.
#       - Butyl Sepharose 4 Fast Flow
#       - Octyl Sepharose CL-4B
#         - Cross-Linked
#       - Phenyl Superose/Sepharose
#         - Phenyl Sepharose High Performance
#         - Phenyl Sepharose CL-4B
#         - Phenyl Sepharose 6 Fast Flow (low/high sub)
#       - Alkyl Superose
#
#   - IMAC
#
#     - Immobilised Metal Ion Affinity Chromatography
#     - proteins-metal complexes
#
#     - Adsorbent
#       - metal chelator
#         - Cu2+
#       - linkage group
#         - iminodiacetic acid
#       - suitable matrix
#         - agarose matrix
#
#     - Binding protein by
#       - His
#       - Cys
#       - Try
#
#     - Elution achieved by
#       - histidine/imidazole
#       - descending pH gradient of histidine/imidazole
#       - compete with protein
#
#   - Biospecific Affinity Chromatography
#
#     - Protein-protein interactions
#       - immobilised transferrin receptor
#       - Specific antibodies
#
#     - Protein-DNA interactions
#       - Heparin columns
#         - Polysaccharide
#         - Containing sulfate groups
#         - mimicking DNA phosphate groups
#
#     - Biomimetic dyes
#
#       - Cibacron Blue F3G-A
#         - Blue Sepharose
#         - analogue of adenylyl-containing cofactors
#         - purification
#           - NAD+ binding enzymes
#           - ATP binding enzymes
#
#       - Procion Red HE-3B
#         - NAD+ binding enzymes
#         - NADP+ binding enzymes
#
#     - Trypsin-like Ser proteases purification
#       - Benzamidine
#       - Arginine
#       - Lysine
#
#     - Purification tau
#       - Over-expression
#       - Blue Sepharose
#       - Mono Q
#       - Gel Filtration
#
#   - Inclusion Bodies
#
#     - Insoluble proteins
#       - produce in E. coli
#       - form inclusion bodies
#
#     - Inclusion bodies
#       - membrane bound vacuoles inside bacteria
#       - isolated once bacteria are lysed
#       - difficult to disrupt
#       - harsh conditions
#         - e.g.
#           - urea
#           - detergents
#           - guanidinium hydrochloride
#         - cause protein denature
#         - need refold
#
#     - Refolding process
#       - gradual remove denaturants
#       - allowing protein fold gradually
#       - via several intermediate states
#
# # 5 Protein Mutagenesis
#
#   - Chemical Mutagenesis
#
#     - GC → AT
#
#     - Hydroxylamine
#       - Converts C
#       - To N4-hydroxycytosine
#
#     - N-methyl-N' nitrosoguanidine
#       - Converts G
#       - To O6-methyl guanine
#
#   - Mutator Bacterial Strains
#
#     - mutD loss
#       - DNA pol. III
#     - mutT loss
#       - prevents A:8-oxidoG
#       - by hydrolysing 8-oxidoG
#     - mutY loss
#       - glycosylase
#       - correct G:A
#       - correct A:8-oxidoG
#
#   - PCR-Mutagenesis
#     - Taq polymerase
#     - Lacks 3’-5’ proofreading activity
#     - Using Mn2+ ↑ error to 30%
#     - Problems
#       - Multiple mutations
#       - Silent mutations
#       - Non-sense mutations 提前终止
#       - No control nature of mutation
#       - Mutations outside cloned gene
#
#   - Site-directed mutagenesis
#
#     - M13
#
#       - Bacteriophage M13
#
#         - ssDNA virus
#         - Replication
#           - ssDNA → ds RF
#           - in E. coli
#         - Recovery
#           - RF M13 DNA
#             - recovered from E. coli
#           - ssM13
#             - recovered from virus
#         - RF DNA → MCS
#
#       - Phagemids 噬菌粒
#
#         - maintain as plasmids in E. coli
#
#         - Plasmids
#           - replication origin
#           - gene expression systems
#
#         - Phagemids Composition
#           - replication origin
#           - packaging signal
#
#         - Infection by helper phage
#           - Phage replication Activate
#           - Phagemid ssDNA → phage particles
#           - Recognizes RF plasmid → ssDNA
#
#     - Overlapping PCR
#
#     - DpnI digestion
#
# # 7 Phage
#
#   - Ff Structure
#
#     - ss circular DNA
#
#     - 11 genes grouped
#       - DNA replication
#         - II
#         - V
#         - X
#       - capsid
#         - VII
#         - IX
#         - VIII
#         - III
#         - VI
#       - membrane associated assembly
#         - I
#         - XI
#         - IV
#
#     - Intergenic (IG) region
#       - encode no proteins
#       - origin sites for +/- strands synthesis
#       - packaging signal
#         - phage particles assembly initiation
#         - hairpin region
#
#   - Ff Life cycle
#
#     - Infection
#     - Conversion to Replicative Form
#     - Phage Genome Replication
#     - Phage Protein Expression
#     - Assembly
#     - Release
#
#   - principle of phage display
#
#     - Fuse protein/peptide to capsid protein
#     - Display capsid protein on surface
#     - Build libraries
#       - per phage:
#       - unique random peptide/protein
#     - Screen using appropriate ligands
#
#   - Natural peptides
#     - Mapping epitopes
#       - monoclonal antibodies
#       - polyclonal antibodies
#     - Generating immunogens
#
#   - Random peptides
#     - Mapping epitopes
#       - monoclonal antibodies
#       - polyclonal antibodies
#     - Identifying peptide ligands
#     - Mapping substrate sites
#       - proteases
#       - kinases
#
#   - Protein and protein domains
#     - Directed proteins evolution
#     - High affinity antibodies isolation
#     - cDNA expression screening
#
#   - Display site
#
#     - site gene
#       - III
#       - VIII
#     - fusions with capsid proteins
#       - pIII
#       - pVIII
#     - Not all sequences displayed well
#
#   - Phage Common problems
#
#     - particle assembly
#     - stability
#     - infectivity
#
#   - Different vector systems
#
#     - Type 3 or 8
#       - either gIII or gVIII
#       - both gene
#
#     - Type 3+3 or 8+8
#       - either gIII or gVIII
#       - only one gene
#
#     - Type 33 or 88
#       - either gIII or gVIII
#       - extra copy: wt gIII or gVIII
#
#     - Valency
#       - pVIII-fusion ＞ pIII-fusion
#
#       - Valency modifications advantages
#         - low affinity interactions
#         - display ‘difficult’ proteins
#
#   - Cysteine problem
#
#   - pIII
#     - 8 cysteines paired
#       - C7-C36
#       - C46-C53
#       - C188-C201
#       - C354-C371
#
#     - Unpaired cysteines problems
#       - odd-numbered Cys affect pIII systems
#       - even-numbered Cys perform better
#       - favors short inter-C sequences peptides
#
#   - pVIII has no cysteines
#
# # 8 MS
#
#   - MALDI
#
#     - Matrix Assisted Laser Desorption Ionisation
#
#     - Role of matrix
#       - ionise sample embedded in crystalline matrix
#       - absorb energy from laser UV
#       - causing sample desorption in gas phase
#       - lead to H+ exchange / ionisation
#
#     - MALDI ionisation
#       - proteins
#       - peptides
#       - sugars
#       - oligonucleotides
#       - synthetic polymers
#
#     - Singly charged ions
#       - large proteins e.g.
#         - bovine serum albumin (BSA)
#         - MW 66.5 kDa
#
#   - ESI
#
#     - Electrospray Ionisation
#     - Proteins with multiple charge
#
#
#   - Protein Digestion
#     - Trypsin
#       - Commonly used
#       - C-terminal side
#       - Lys
#       - Arg
#
#     - e.g. LDFPQRILLWKAGGT
#       - LDFPQR
#       - ILLWK
#       - AGGT
#
#   - LC-MS/MS
#     - Sequencing
#       - MS (Q-TOF)
#         - Quadrupole-Time Of Flight
#         - Q1
#           - select desired m/z peptide ion
#         - collision cell q2
#           - Collision induced dissociation (CID)
#             - peptide ions
#               - 2+
#               - 3+
#
#             - N-terminal
#               - a
#               - b
#               - c
#
#             - C-terminal
#               - x
#               - y
#               - z
#
#         - TOF mass analyser
#
#     - modification identification
#       - Phosphorylation
#       - Glycosylation
#       - Oxidation
#
#   - Fragments
#     - b, y ions dominate
#     - Given a reasonable series of b / y ions
#       - Peptide sequenced partially
#     - Impossible to distinguish
#       - Leu
#       - Ile
#     - Require high resolution
#       - Lys
#       - Gln
#
#   - Identify protein
#     - 6 or 7 contiguous aa
#     - 18-21 DNA bases
#
# # 9 AUC
#
#   - Analytical Ultracentrifugation
#
#   - high-speed centrifuge → biomolecules sedimentation
#
#   - Optical detection systems
#     - monitored sedimentation
#       - protein solute absorbs UV
#       - solvent doesn’t
#     - specific, protein absorbs at particular wavelengths e.g.
#       - aromatic aa
#       - bound metal
#       - cofactor e.g.
#         - NAD+/H
#         - FAD/H2
#
#     - Interference
#       - Relative refractive index between
#         - sample
#         - reference solution
#       - Universal detection
#         - × need absorbing protein
#       - not specific
#
#     - Fluorescence
#       - sensitive
#       - specific
#         - defined excitation
#         - emission wavelengths
#
#   - Svedberg equation
#     - s =
#       - DM
#       - (1-vρ)
#       - 1/RT
#
#   - Non-equilibrium Sedimentation
#     - very fast
#       - 60,000 rpm
#     - no back-diffusion
#     - 3 forces
#       - centrifugal force
#         - spin of centrifuge
#       - buoyancy force
#         - solute displacing solvent molecules
#       - frictional force
#         - restriction of solute passing through solvent
#     - s determination
#       - diffusion coefficient D
#         - shape
#       - molecular weight M
#         - size
#     - e.g.
#       - two non-interacting proteins
#         - 2 distinct sedimentation events
#         - 2 s determined
#       - proteins interact
#         - boundary due to complex
#
#
#   - equilibrium Sedimentation
#     - slower
#       - 10,000 rpm
#     - balanced by diffusion back up the cell
#     - take many hours
#     - molecular weight M
#     - replaced by MS
#     - show protein self-association
#     - e.g. protein in monomer-dimer equ.
#       - low conc. (absorbance)
#         - monomeric
#       - high conc. (absorbance)
#         - dimeric
#
#
# # 10 SPR
#
#   - Physical Principle
#
#     - total internal reflection
#       - Light passing through a prism
#
#     - Surface Plasmon Resonance
#
#       - Surface Plasmon
#         - e- oscillations
#         - prism upper surface
#           - coated with thin modified gold
#             - Lys
#             - Cys
#
#       - Resonance
#         - incident light
#           - between light and surface
#         - plasmons achieve
#           - reflected light intensity → minimum
#
#   - Application
#
#     - immobilising protein +
#       - e.g. antibodies
#     - gold
#     - passing interacting molecules
#     - θ_SPR changes
#       - sensitive to refractive index
#       - binding can be detected and studied
#     - done in flow cell
#     - Pure analyte samples are required
#
#   - Sensorgram
#
#     - analyte injection
#       - association: analyte and immobilised protein
#
#     - pure buffer injection
#       - induces dissociation of complex
#
#     - regeneration buffer injection
#       - strip the complex
#       - residual bound analyte removal
#
#     - normal buffer
#       - resets system for another cycle
#
#   - Data
#     - Kinetics
#       - association rate
#           - P = k1[A][P]
#       - dissociation rate
#           - P = k-1[AP]
#     - Thermodynamics
#       - dissociation constant
#         - [A][P]/[AP] = k-1 / k1
#     - Accurate range
#       - nM
#       - μM
#
# # 11 Fluorescence, FRET
#
#   - Fluorescence
#     - Stokes shift
#       - Change in wavelength
#     - Quantum yield
#       - Fraction
#       - emit fluorescence
#       - excited molecules
#     - Photobleaching
#       - photochemical destruction of fluorophore
#       - cause by Extended exposure to intense excitation light
#
#     - Fluorophore
#       - Polarised chromophore
#       - Intrinsic fluorophores
#         - aromatic aa
#           - tryptophan (indole ring)
#         - flavin
#         - NADH cofactors
#       - Extrinsic fluorophores
#         - attached or bound to protein
#
#       - efficiency
#         - dependent on environment
#           - λ (emission)
#           - quantum yield (signal)
#
#
#     - Monitor protein folding
#       - different fluorescence
#         - surface tryptophan residue exposed to water
#         - buried inside the protein core
#       - no tryptophan
#         - extrinsic fluorophore introduced chemically
#
# fluorophore + protein non-covalently
# λ(emission), quantum yield (signal) change
#
# bovine serum albumen (BSA)
#
# BSA binds lipids in transport through blood
#
# extrinsic fluorescent compound ANS + BSA
# fluorescence change
# moves from the
# polar environment
# water to the
# non-polar environment
# protein
#
#   - Anisotropy
#     - fluorescence difference in directions
#     - detect biomolecular interactions
#     - uses plane polarised light
#
#     - large molecules
#       - tumble slowly
#       - emit highly polarised light
#
#     - small molecules
#       - tumble rapidly
#       - emit depolarised light
#       - reduced anisotropy
#
#     - e.g.
#       - [DNA_fluor+CAP+RNA pol] complex
#         - fluorescent-labelled DNA
#         - RNA pol enzyme
#         - small protein ‘CAP’
#       - RNA pol conc. ↑
#       - slower tumbling
#       - anisotropy ↑
#
#   - FRET
#
#     - Förster Resonance Energy Transfer
#       - Two different fluorophores
#       - Donor selectively irradiated
#       - Acceptor quenched fluorescence
#         - overlaps
#           - donor emission spectrum
#           - acceptor excitation spectrum
#         - donor / acceptor close in space
#
#     - Förster distance
#       - distance at 50% FRET efficiency
#
#     - Measuring spatial proximity
#       - relative motion, conformational flexibility of a protein
#       - dissociation of 2 linked fluorescent protein
#
# # 12 NMR
#
#   - 2D
#     - signal correlated with each other
#     - coupled nuclei
#       - homonuclear
#       - heteronuclear
#     - coupling
#       - bonds (scalar, J)
#       - space (dipolar, d)
#
#   - COSY
#     - Correlated Spectroscopy
#     - 1H-1H
#     - homonuclear
#     - through bond
#
#   - NOESY
#     - Nuclear Overhauser Effect Spectroscopy
#     - 1H-1H
#     - homonuclear
#     - through space
#     - nuclear Overhauser effect (nOe)
#       - between protons held rigidly in close proximity due to secondary structure
#     - Patterns in 1H1H NOESY between contiguous AAs can reveal the presence of an alpha helix or beta sheet
#
#     - Heteronuclear
#       - important for larger proteins (>100 aas)
#       - line broadening in 1H-1H experiment
#       - Coupling between 13C, 15N, 1H
#       - require 13C-, 15N-labelled protein
#
#   - 3D
#     - The process of assigning signals in
#     2D NMR to specific AAs, then
#     determining their spatial relationships
#     is a complex process (even with
#     knowledge of the sequence)
#     - It requires considerable skill and time,
#     but can result in a 3D structure
#     - The process is performed in
#     combination with molecular modelling
#
#   - slow tumbling
#
#     - small fluorescent ligand +
#     - large protein →
#     - tumbling rate ↓
#
#     - Tumbling increase in horizontally polarised signal
#
#   - CSP
#     - chemical shift perturbation
#     - By titrating in a ‘binder’
#       - small molecule ligand
#       - another protein
#
#     - map binding sites
#       - aa CSP peak
#         - where the binder interacts
#
#   - native ESI-MS
#
#     - study protein complexes
#     - volatile buffer
#       - ammonium acetate
#     - give lower charge states
#       - protein is still folded
#       - surface area to accept protons
#
# # 13 Evolution
#
#   - Divergent evolution
#     - 趋异进化
#     - Darwin’s finches
#     - ABO blood groups
#       - A and B alleles
#         - differ at 4 aa
#       - O gene
#         - premature stop
#         - too short to work
#
#   - Convergent evolution
#     - 趋同进化
#     - Top marine predators
#       - Similar body plan
#       - But came from Different land creatures
#       - Functionally convergent
#       - Doesn’t look similar
#     - Enzymes work same reaction
#       - e.g. from fungus
#         - Cellobiohydrolase
#         - Exoglucanase 1
#       - differ in fold / mechanism
#       - same result
#
# # 16 Protein structures
#
#   - Peptide
#     - ribosome
#       - 4.5 MDa
#       - 4 different RNA molecules
#       - 82 proteins
#
#     - tRNAs
#       - 25 kDa
#       - 20 aminoacyl-tRNA synthetases
#       - All to add ~110 Da aa
#
#     - Ramachandran plot
#       - Real data from protein structures
#       - Only some conformations occur
#         - α-helix
#         - β-sheet
#       - More flexible
#         - Glycine
#       - Less flexible
#         - Proline
#
#   - Secondary structure
#
#     - α-helix
#       - stabilized by H bond
#       - 3.6 aa / turn
#       - 2 side different
#         - Non-polar
#         - Polar
#
#     - β-sheet
#       - parallel
#       - anti-parallel
#       - Linker
#         - loops
#         - turns (random coils)
#
#   - Tertiary structure
#
#     - salt bridges
#       - charged side chains
#       - Ionic interactions
#
#     - disulfide bridges
#       - Cys
#
#     - secondary structure → Motif e.g.
#       - β-α-β loop
#
#     - Motif → domain e.g.
#       - α-β barrel
#
#     - domain → Protein
#       - domain have specific function
#         - binding to substrate
#         - receptor
#
#   - Quaternary structure
#
#     - single peptide chain
#       - monomeric
#
#     - multiple polypeptides
#       - identical polypeptides
#         - from same gene
#         - homo- prefix
#       - different polypeptides
#         - from different genes
#         - hetero- prefix
#       - Dimers
#       - Tetramers
#       - Octamers
#
#     - bonding interactions
#       - H-bonding
#       - salt bridges
#       - disulfide bridges
#
#     - Subunit
#       - Each polypeptide unit
#
#   - Proteins in motion
#     - change shape
#       - enzyme binding substrate
#     - more distant
#       - inhibitor binding
#     - couple to other reactions
#       - ATP hydrolysis providing energy
#     - Allosteric
#       - functional units assemblies
#       - quaternary structural transitions
#         - response to conc. ligand changes
#
# Hemoglobin (Hb)
# response to allosteric effectors
# cooperative binding
# one subunit binding affects other
# hemoglobin sigmoidal curve
#
# Myoglobin
#
# # 17 Cofactors
#
#   - Prosthetic groups
#     - Aid structural stability
#     - Porphyrin
#
#   - Apoenzyme
#     - enzyme without cofactor
#
#   - Coenzymes
#
#     - Functionally complement with aa
#
#     - NAD
#       - Nicotinamide adenine dinucleotide
#       - Aid redox reactions
#         - NAD+ accepts
#         - H- from -OH
#       - Bind transiently
#
#     - TPP
#       - Thiamine pyrophosphate
#       - Vitamin B1 derivative
#       - Involved in forming / breaking C-C bonds
#       - e.g.
#         - Pyruvate decarboxylase
#
#     - Cobalamin
#       - Vitamin B12
#       - Co cycles (I, II, III)
#       - R group
#         - CN
#         - HO
#         - Me
#       - e.g.
#         - Methionine synthase
#
#     - Biotin
#       - Vitamin B7
#       - Carboxylate Transfer
#       - e.g.
#         - Pyruvate carboxylase
#
#     - PLP
#       - Pyridoxal phosphate
#       - Vitamin B6
#       - Forms Schiff base
#       - Function
#         - amino transferases
#         - eliminations
#         - isomerisations
#
# # 18 Kinetics
#
#   - Assumption
#     - Substrate excess
#     - Rapid equilibrium
#     - Enzyme unchanged
#       - Free E
#       - ES
#
#   - Assume [ES] steady state
#     - Formation
#       - ES =k1[E][S]
#     - Breakdown
#       - ES = k-1[ES]+k2[ES]
#     - Formation = Breakdown
#
#   - v =
#     - (Vmax * [S])
#     - / (Km + [S])
#
#   - Vmax
#     - all enzyme involved
#     - limited by k2
#
#   - Km, Michaelis constant
#
# # 25 Enzymology
#
#   - Biotechnology
#
#   - Role
#
#     - Metals
#
#       - Metals in biological systems
#         - Metalloproteins
#           - Electron transport
#           - Oxygen carriers
#           - Structural role
#           - Metalloenzymes
#             - Hydrolytic enzymes
#             - Two electrons redox enzymes
#             - Multi electron pair redox enzymes
#             - Rearrangements
#         - Structural or communication role
#
#       - Group 1/2 metals
#         - Group 1/2 metals: structural role in
#           - body (e.g. bones)
#           - protein folding
#         - Group 1/2 metals: Aid in
#           - charge maintenance
#           - osmotic balance
#           - nerve impulses
#       - Transition metal ions
#         - structural role
#         - electron carries
#         - oxygen transporters
#         - catalysts in redox/non-redox
#
#     - aa
#
#       - Proteins bind to metal
#       - Prosthetic groups bind to metals
#       - According to the HSAB
#
#   - Serine proteases
#
#     - Triad
#       - Asp
#         - align His
#         - act as Acid
#       - His
#         - activate Ser
#         - act as Base
#       - Ser
#         - act as Nucleophile
#
#     - Two steps
#       - Formation of acyl-enzyme + Ser
#       - Hydrolysis of acyl-enzyme
#
#     - No substrate specificity
#       - main chain binds enzyme loop
#       - Backbone H-bonds form
#       - Interaction resembles
#         - short anti-parallel β-sheet
#
#     - selectivity controlled by pocket
#
#       - Trypsin
#         - Aspartate
#         - Negative charge
#       - Chemotrypsin
#         - Serine
#         - Small
#       - Elastase
#         - Valine
#         - Threonine
#         - Bulky
#
#
#   - Cysteine proteases (Thiol proteases)
#
#     - e.g.
#       - papain 木瓜蛋白酶
#       - ficin 无花果蛋白酶
#       - bromelain 菠萝蛋白酶
#
#     - no Asp need
#       - pKa: Cys(1.92)＜Ser(13)
#
#     - Mechanism for papain
#       - Catalytic dyad
#         - Cys
#           - 25
#           - nucleophilic attack
#         - His
#           - 159
#           - general acid/base
#       - Oxyanion hole stabilize by
#         - Cys25
#         - Gln19
#         - H-bonding interactions
#       - Substrate binding
#         - 7 aa
#
#   - Acid proteases (Aspartic proteases)
#
#     - Asp in active site
#     - e.g.
#       - pepsin 胃蛋白酶
#       - chymosin 凝乳蛋白酶
#       - HIV-protease
#     - acid/base cat. mechanism
#
#   - Metalloprotease
#
#     - cleave peptide bond
#     - Require Zn & Co
#     - Exopeptidases
#       - Process from 2 end
#       - cleave terminal / penultimate peptide bond
#       - Releasing aa / dipeptides
#     - Endopeptidases
#       - Break from non-terminal aa
#       - Specific for certain aa
#
#   - Zn
#
#     - e.g.
#       - Carbonic Anhydrase
#         - reversible CO2 to -COOH
#       - Carboxypeptidase A
#         - Exopeptidases
#       - SuperOxide Dismutase
#         - maintain protein structure and stability
#       - β-lactamase
#         - hydrolytic enzymes
#       - alcohol dehydrogenase
#
#     - × catalyse redox reaction
#
#     - Carboxypeptidase A
#       - Exopeptidases
#
#       - Coordination, Carboxypeptidase A
#         - 2 His
#         - a Glu
#         - a water/hydroxide
#         - Distorted Td
#       - Remove Zn
#         - low pH, chelating agent
#           - loss activity
#           - no effect on structure
#         - Re-established: Zn + apo enzyme
#       - Cleaving peptide from C-term, favoured:
#         - Phe
#         - Tyr
#         - Trp
#         - Leu
#       - Zn2+ polarises C=O
#       - Residues act as acid/base
#       - concerted mechanism
#
#     - Carbonic Anhydrase
#
#       - Catalyse
#         - reversible CO2 to -COOH
#       - Regulate
#         - pH
#         - haemoglobin function
#       - Coordination, Carbonic Anhydrase
#         - 3 His
#         - 1 HO-
#         - Distorted Td
#         - 1 nearby Thr/His aided formation of hydroxide
#       - One of fastest enzymes
#         - diffusion limited
#       - Zn2+ + H2O → HO- attack CO2
#
#   - Fe
#
#     - Most abundant transition metal in human body
#       - (~4-6 g)
#
#     - Fe associated-diseases
#       - anaemia
#       - haemochromatosis
#       - siderosis
#
#     - Transport
#       - Transferrins
#         - Bind Fe(III)
#         - In pH dependent manner
#       - 2 Fe and 2 Carbonate in Distorted Oh
#
#     - Storage
#       - Ferritins
#         - Phase transition: metal ions —— solid
#       - In anaerobic
#         - Fe(II) (soluble)
#       - In aerobic
#         - Fe(III) (solubility of ~10^-18 M)
#       - In protein centre
#         - Fe(III) stored Fe₂O₃·xH₂O
#
#     - Structural motifs
#       - haem
#         - Porphyrin
#       - non-haem
#       - Fe-S clusters
#
#     - Roles
#
#       - Oxygen transport and storage
#         - Haemoglobin 血红蛋白
#           - oxygen transport
#         - Myoglobin 肌红蛋白
#           - oxygen storage
#         - Both contain haem centre, coordinating
#           - Fe(II)
#             - deoxy
#           - Fe(III)
#             - oxy
#
#       - Electron transfer
#         - Cytochrome c
#           - Mitochondrial Cyt c transfers e- in respiratory chain
#           - Haem-Fe centre
#           - Coordination, Cyt c
#             - His
#             - Met
#             - in axial positions
#
#         - Fe-S proteins
#           - Fe in Td
#           - S2- / —S- from Cys
#             - 4Fe4S
#             - 3Fe4S
#             - 2Fe2S
#           - Fast e- transfer tuned by H-bonds around
#
#       - Catalysis
#         - Some Fe-S clusters have hydrolytic activity
#         - Haem / non-haem centres found in Fe enzymes
#
#       - Oxygen activation
#         - SuperOxide Dismutase
#         - Catalase 过氧化氢酶
#         - Lower activity → O2-derived radicals accumulation → oxidative stress
#         - Oxygen Activation Type
#           - Dioxygenases
#           - Monooxygenases
#           - Oxidases
#
#     - P450
#
#       - Two main roles
#         - Endogenous Biosynthesis/degradation
#           - specific for substrate
#             - steroids
#             - fatty acids
#           - High regio- and stereoselectivity
#         - Exogenous Oxidative Metabolism
#           - e.g. drugs
#           - Low selectivity
#
#       - Haem-based
#       - Monooxygenases
#       - 2e-/2H+ hydroxylation
#       - Breaking strong C-H bonds
#       - Triggered by substrate
#       - Fe cycles (II, III, IV)
#       - aided by non-innocent ligand porphyrin ring
#
#   - Cu
#
#     - Hemocyanin 血蓝蛋白
#       - Cu-based
#       - oxygen transport protein
#       - In invertebrates
#
#     - Type I
#       - mononuclear Cu sites
#       - intense blue colour
#       - high reduction potential
#       - Type I Cu coordinated by
#         - 2 His
#         - 1 Cys
#         - 4th ligand (e.g. Met)
#
#     - Type II
#       - mononuclear Cu sites
#       - N or N/O coordination
#       - square planar / JT distorted Oh
#       - Colour not intense
#
#     - Type III
#       - 2 Cu ← His
#       - EPR silent
#         - due to antiferromagnetic coupling
#
#     - LPMOs
#       - Lytic Polysaccharide Monooxygenases 裂解多糖单加氧酶
#       - Type II
#       - Coordination, LPMOs
#         - 3 H2O
#         - a His
#         - a Tyr
#         - “His brace”
#       - 2e-/2H+ hydroxylation
#       - Selective oxidation
#         - C1
#         - C4
#       - breaking strong C-H bonds
#       - triggered by substrate
#       - Cu cycles (I, II(III)) producing O2 intermediates similar P450
#
#     - GalOx
#       - Function
#         - -OH + O2 → -CHO
#         - Anti-bacterial H2O2 production
#         - 2e-/2H+ removed from -OH, reduce O2 to H2O2
#       - Coordination, GalOx
#         - 2 His
#         - 2 Tyr
#         - 1 H2O
#         - modified Tyr-Cys
#         - distorted square pyramidal
#       - Many substrates
#         - not just galactose
#         - aliphatic
#         - aryl alcohols
#         - sometimes with high substrate selectivity
#       - Active site
#         - modified Tyr-Cys
#         - Aid in e- transfer
#       - Cu cycles (I, II) aided by active site residues
#
#   - SODs (Superoxide Dismutase)
#
#     - ROS
#       - Produced by O2 activation
#       - 3 Anti-oxidant enzymes
#         - Superoxide Dismutase 歧化酶
#           - HO2 → H2O2 + O2
#         - Catalase 过氧化氢酶
#           - Fe-haem enzyme
#           - H2O2 → O2 + water
#         - Glutathione Peroxidase
#           - Selenoprotein
#             - Seleno-cysteine, Sec
#           - Reduce H202 → water
#           - Oxidising glutathione 2GSH → GSSG
#             - Glu
#             - Cys
#             - Gly
#
#     - Fe/MnSOD
#
#       - eukaryotes/prokaryotes
#       - homodimer/homotetramer
#       - Active site is coordinated by
#         - 3 His
#         - 1 Asp
#       - MnSOD in
#         - all mitochondria
#         - some bacteria
#
#     - NiSOD
#
#       - last class to be discovered
#       - prokaryotes
#       - homohexamer
#       - 1 Ni active site/subunit
#       - Hydrophobic core → assembly of quaternary structure
#       - Ni binding hook
#         - Binding site disordered without metal
#         - Pro causes turn
#
#     - Cu&ZnSOD
#
#       - In all eukaryotes
#       - Both Cu / Zn in active site
#       - Zn role in SOD
#         - structural role
#       - Cu role in SOD
#         - catalysis
#       - Bridged by 1 imidazolate
#
# # 26 Q1
#
#   - Protein folding
#     - Diseases
#       - Partially unstructured proteins
#         - aggregation
#       - Neurodegenerative disease
#     - Function
#     - Design
#
#     - Golf course landscape
#       - Single low energy conformation
#       - Random search of conformational space
#       - Very slow folding
#
#     - Rugged funnel landscape
#       - Reduces conformational search
#       - Hierarchical folding – structure complexity increases gradually
#       - Allows fast folding (ms to s)
#
#     - Proteins stabilized by non-bonding interactions
#       - H-bond
#       - Hydrophobic
#       - Electrostatic
#       - Van der Walls
#
#     - Factors drive protein denaturation
#       - Temperature
#       - pH
#       - Detergents
#       - High concentration of water soluble compounds (e.g. alcohols)
#       - Salts
#
#   - Protein composition
#     - 50 to 400+ L-aa
#     - PTMs
#       - Disulphide bonds
#       - Proteolytic cleavage
#       - Modification of aa
#     - Phosphorylation
#       - Most abundant PTM in Eukaryotes
#     - Glycosylation
#       - folding
#       - stability
#       - signalling
#     - Modified proteins might not refold if unfolded
#
#   - Ramachandran plot
#
#     - α-helix
#       - φ ≈ -60°
#       - ψ ≈ -45°
#       - angles close together
#     - β-sheet
#       - φ ≈ -120°
#       - ψ ≈ 120°
#       - angles farther apart
#
#   - Thermofluor assay
#     - Protein Stability
#       - Tm
#         - melting temperatur
#         - midpoint in unfolding process
#       - Cofactors, ligands can stabilise
#         - Cu on stability of LPMOs
#     - Thermofluor analysis
#       - differential scanning fluorimetry
#
#     - Protein + fluorescent dye + cuvette
#       - fluorescence quenched by water
#       - T ↑
#       - protein unfold
#       - dye bind hydrophobic residues
#       - expelling water
#       - fluorescence ↑
#
#
#
#
#   - spectroscopic techniques anlysis
#     - secondary protein structures
#     - tertiary protein structures
#
#   - effect of denaturants
#     - stability
#     - energy barriers in two state system
#
#   - Secondary Structure Prediction
#
#     - β-sheets
#       - Sequence rich
#         - Val
#         - Thr
#         - Ile
#         - Tyr
#       - P & G
#         - STOP signal
#         - reverse turn facilitating
#           - anti-parallel β-hairpin
#
#     - α-helices
#       - Sequence rich
#         - Ala
#         - Leu
#         - Lys
#         - Glu
#       - periodicity of side chains
#         - i to i+3 / i+4
#         - favourable helix stabilising interactions
#       - Amphipathic helix
#         - one polar
#           - solvent exposed
#         - one non-polar face
#           - packing against core
#       - P & G
#         - STOP signal
#
#
#   - peptide bond characteristics
#     - resonance
#       - rigid
#       - planar
#     - planarity restricts rotations
#
#   - principle of higher order assembly of coiled coils structures
#
#     - importance of the heptad repeat
#     - Pseudo heptad repeat
#     - abcdefg:a’b’c’d’f’g’
#
#   - Parallel dimer
#     - a b c d e f g : a b c d e f g
#       - a, d
#         - Leu
#         - Val
#       - b, c, f
#         - anything
#       - g and e
#         - complementary charges
#
#   - Anti-parallel dimer
#     - a b c d e f g : a’ b’ c’ d’ e’ f’ g’
#       - a, d
#         - Leu
#         - Val
#       - b, c, f
#         - anything
#       - e = g
#       - e’ = g’
#
#   - De novo design
#
#   Cys-His-Glu triad (found in
#   natural ester hydrolases)
#   mutated into the centre of the
#   four-heptad repeat
#
#   Hydrolases p-Nitrophenyl
#   acetate to p-Nitrophenol
#
#   Synthetic coiled coils designed
#   to mimic carbonic
#   anhydrase/nitrite reductase
#
#   - non-natural aa in foldamer structures
#
#     Non-natural synthetic oligomers (foldamers) follow
#     different folding rules
#
#     Peptidomimetics
#     resistant to proteases
#
#     2.5 residues per turn
#     H-bond: C=O (i), NH (i+3) and N’H (i+4)
#     more H-bond
#
#     Self-assembly of a hexameric helix bundle
#     Helical arrangement not affected by side chains
#     Self-assembly controlled by side chains, driven by hydrophobic core formation
#     Complementary surface charges
#
#     Self-assembly of a hexameric channel/pore
#     Self-assembly controlled by side chains, driven by hydrophilic pore formation
#     Surface hydrophobic residues
#
#   - Peptide Synthesis
#
#     - Solid Synthesis
#       - Coupling
#       - Deprotection
#         - 20% piperidine/DMF
#       - Coupling
#         - DCC/HOBt
#         - DCI/Oxima
#       - Capping
#         - acetic anhydride
#       - Repeat steps
#       - Cleave from resin
#         - TFA
#
#
#     - Protecting Group
#       - Boc
#         - Lys
#
#       - tBu
#         - Ser
#         - Thr
#         - Tyr
#
#       - OtBu
#         - Asp
#         - Glu
#
#       - Trt
#         - Cys
#
# # 27 Q2
#
# - Translate between genetic code and primary sequence
# - Design DNA/RNA sequences to introduce mutations
# - Compare alignment scoring matrices to biochemistry of proteins
#
#
# - Understand how protein structure is coupled to biological function
#
# - Know the key techniques in determining the structure of proteins
# - Appreciate the advantages and limitations of different analytical techniques
# - Identify what analytical technique may be most useful in set situations
#
# - NMR spectroscopy
#
# - Cryo-EM
#   - Purify protein
#   - Plunge-freeze
#   - Transfer to TEM
#   - Image specimen
#   - Analyse & reconstruct
#
#
# - Define bioinformatics
#   - Bioinformatics is an interdisciplinary field that
#   - develops methods and software tools for understanding biological data in particular
#   - when the data sets are large and complex
# - Understand link between the key “omics”
#   - transcription
#   - translation
#   - enzymatic activity
# - Demonstrate cutting-edge applications of bioinformatics
#   - COVID genome sequencing
#   - Predicting protein folding
#
#
# - Understand library scale and use of plasmids
# - Describe the key methods of protein design
# - Compare protein design methods and identify key uses
# - Appreciate protein design in sensor applications
#
# # 28 Q3
#
# - Show the binding modes of the side-chains of amino acids to d-metals.
# - Understand the connection between the structure of a metalloprotein, the electronic structure of a metal centre in biology and its function.
# - List the structural and spectroscopic methods that will be described in this course.
# - Explain crystal field theory and apply it to derive approximate d-orbital splitting diagrams for some metal sites in biology.
#
# - nλ = 2dsinθ
#
#
# ## 28.1 X-ray
# - Describe why you would want to undertake a protein X-ray crystallographic study.
#
# - overview of X-ray crystallography.
#   - Single Crystal Formation
#     - single crystal is exposed to X-rays from an X-ray source
#   - Data Collection
#     - scattered X-rays are captured on a detector (e.g., film)
#     - producing diffraction pattern (precession photograph)
#   - Data Processing
#     - diffraction pattern → electron density map
#   - Model Building
#     - map + sequence = atomic structure of the protein
#
# - features of X-ray diffractometer.
# X-ray Source
# rotating copper (Cu) anode
# generates X-rays
# 50 keV electrons
# Mirrors
# X-ray mirrors focus and direct the X-ray beam toward the crystal.
# Crystal Holder
# The crystal is mounted on a rotating platform to expose it to X-rays at different angles.
# Detector
# Detects the diffracted X-rays
# creating a pattern (red dots) that can be analyzed to determine the crystal structure.
#
# - Compare and contrast magnification and diffraction as ways of viewing small objects.
#
# - Understand the implications of the phase problem in crystallographic determinations
#
# Some information is lost
# X-ray scattering is recorded
# wave amplitudes are retained
# relative phases are lost
#
# - outline approaches to solve it.
#
# Isomorphous replacement
# the insertion of a heavy metal atom into the protein without destroying the crystal.
# This can be achieved by soaking a protein crystal in a solution containing a heavy metal salt.
#
# Imagine in real space
# creating a 'difference crystal' by subtracting the native crystal from the derivative crystal.
# dominated by the high number of electrons associated with the heavy atom.
#
# PATTERSON SYNTHESIS
# leads to a map that resembles an electron density map.
# contains sufficient information to locate the position of the heavy atoms in the structure.
#
# calculation in which we set all of the phases to zero and just
# use the intensities of this difference diffraction pattern.
#
#
# - Appreciate that regular arrays of matter give rise to diffraction patterns that are related to the structure of the material by the Fourier Transform.
#
# - Derive the Bragg Equation and
#   - use it to determine the resolution of a crystallographic study.
# - process of refining a structure.
#
# - Assess the quality of a protein X-ray crystallographic study.
#
# ## 28.2 XAS
#
# - origin of features
# - Appreciate the information content in each feature
# - advantages and disadvantages of EXAFS as a structural tool.
# - Use the Bond Valence Sum to analyse EXAFS data and predict EXAFS spectra for metal centres in proteins.
# - Understand the need for synchrotron sources for XAS (and protein crystallographic) studies.
#
# ## 28.3 EPR
#
# - Describe the EPR experiment and how EPR spectra are presented.
# - EPR g- and A-values.
# - Classify EPR spectra as
# isotropic,
# axial or
# rhombic and
#
# - effect of anisotropy on the form of frozen solution EPR spectra
#
# - Provide an explanation for the variation of the g-value and how this relates to electronic structure
#
# - Provide interpretations for the EPR spectra of Cu(II) containing compounds and proteins
#
# # 50 HCC & CRLM
#
# ## 50.0 Acquisition / Processing
#
#   - TCGA database
#     - RNA expression profiles
#     - clinical data
#     - via UCSC Xena platform
#
#   - survival analysis
#     - 368 samples
#
#   - Processing
#     - TPM format
#     - log2-transformed
#
#   - sc
#
#     - sc dataset
#       - GEO
#       - 10 HCC
#       - 9 CRLM
#
#     - Quality control criteria
#       - mitochondrial content
#         - ＜ 20%
#       - UMI counts
#         - 200-20,000
#       - gene counts
#         - 200-5,000
#
#     - Seurat functions
#       - NormalizeData
#         - Data normalization
#       - FindVariableFeatures
#         - selection of highly variable genes
#         - 2000 genes
#       - ScaleData
#         - data transformation
#         - eliminating cell cycle effects with the parameters
#         - vars.to.regress = c("S.Score", "G2M.Score")
#
#       - Dimensionality reduction methods
#         - UMAP
#         - TSNE
#         - Louvain
#
#     - Batch effect correction
#       - Harmony
#
#     - Differential gene expression
#       - Between
#         - clusters
#         - cell types
#       - FindAllMarkers function
#         - p-value < 0.05, log2FC > 0.25
#         - expression proportion > 0.1
#
#   - ST
#
#     - HCC ST
#       - 4 HCC samples
#     - CRLM ST
#       - 4 CRLM samples
#
#     - SpaceRanger software
#       - Post-quality control
#
#     - SCTtransform algorithm
#       - data normalization
#       - selection of highly variable genes
#       - data transformation
#
#     - average number of spots
#       - 4054
#     - average UMI
#       - 15317.4
#     - gene counts
#       - 3890.1
#     - mitochondrial content
#       - 4.5%
#
#     - Seurat
#       - Analysis
#       - visualization
#
#     - CARD algorithm
#       - conditional autoregression based deconvolution
#       - Deconvolution analysis
#
#     - single-cell annotations
#       - cell type predictions for each spot
#
#     - CARD software
#       - Visualization of cell types in ST
#
#     - Signature scores
#       - Seurat
#         - GSVA package
#         - AddModelScore
#
# ## 50.1 sc Expression Profile
#
#   - Markers
#
#     - epithelial cell
#       - EPCAM
#       - KRT18
#       - KRT19
#       - CDH1
#
#     - fibroblast
#       - DCN
#       - THY1
#       - COL1A1
#       - COL1A2
#
#     - endothelial cell
#       - PECAM1
#       - CLDN5
#       - FLT1
#       - RAMP2
#
#     - T cell
#       - CD3D
#       - CD3E
#       - CD3G
#       - TRAC
#
#     - NK cell
#       - NKG7
#       - GNLY
#       - NCAM1
#       - KLRD1
#
#     - B cell
#       - CD79A
#       - IGHM
#       - IGHG3
#       - IGHA2
#
#     - mast cell
#       - KIT
#       - MS4A2
#       - GATA2
#
#   - Pearson correlation matrix
#     - correlation between two continuous variables
#       - clustering results
#       - cell type classification
#     - marker gene expression
#     - heatmap
#
#   - Marker gene expression
#     - heatmaps
#     - tSNE plots
#     - confirming cell-type identification
#
#   - Comparisons
#     - cell type composition
#     - patient origin
#     - cell count
#     - transcript detection
#     - CNV status
#
# ## 50.2 ST
#
#   - HCC enriched
#     - LIHCT
#     - tumor cells
#   - CRLM enriched
#     - LIHC
#     - fibroblasts
#     - endothelial cells
#     - myeloid cells
#
#   - CNV detection
#     - InferCNV software
#     - CNV score distribution
#
#   - deconvolution analysis
#     - CARD algorithm
#     - based on single-cell data
#     - cell type distribution
#
#
#   - H&E staining images
#
#   - tumor vs. non-tumor classification
#
#     - dimensionality reduction
#     - clustering analysis
#
#
#
#     - tumor cells
#     8 subgroups
#     LIHCT1
#     LIHCT3
#     LIHCT4
#
#     tSNE plot
#     subgroup composition
#     sample origin
#     CNV status
#     patient composition
#
#     Marker genes for each subgroup were calculated
#     expression heatmaps were created
#
#
#
#     - non-tumor cells
#     5 subgroups
#     endothelial cells
#     tumor cells
#     myeloid cells
#
#     LIHCT2 enrichment
#
#     tSNE plot
#     marker gene expression heatmaps
#
# ## 50.3 Subclassification Analysis of Tumor Cells
#
# Tumor cells were isolated and subjected to dimensionality reduction and clustering analysis, resulting in 16 clusters. These clusters were then merged based on their marker gene functions, yielding 7 tumor cell subgroups (Figure 3A). A bar plot displays the cell composition of each sample, showing that HCC samples have a higher content of APOA2+NEO cells, while CRLM samples have a higher content of TFF3+NEO cells. Differential gene expression analysis was performed for each subgroup, and a heatmap of differentially expressed genes was generated (Figure 3B). GO Biological Process (GOBP) enrichment analysis was conducted for the marker genes of each subgroup, revealing their corresponding functions. We compared the CNV differences among different cell types from different sample origins, finding significant differences in CNV across most cell types (Figure 3C). Transcription factor analysis was also performed for each cell type, with the results visualized in a heatmap showing different transcription factors enriched in various cell types (Figure 3D).
#
# Subsequent cell trajectory analysis revealed multiple paths leading to different endpoints, indicating the potential existence of different subtypes. The starting branches contained a large number of APOA2+NEO cells and tumor cells from HCC (Figure 3E). From the pseudotime analysis, APOA2+NEO cells were primarily at the starting points, while most other cells were at the endpoints. Genes related to pseudotime were identified, and their expression heatmap was generated (Figure 3F). Scatter plots of pseudotime for six selected tumor marker genes (APOA2, HIST1H2AG, HMGB2, IGKV1-5, LCN2, TFF3) were created (Figure 3G).
#
# ## 50.3 Cell Annotation Analysis
#
#   - tumor heterogeneity clustering
#     - epithelial cells
#     - immune cells
#     - fibroblasts
#
#
# ## 50.4 Subgroup Analysis of Cell Populations
#
#   - further distinction for subgroups
#     - Immune cells
#     - epithelial cells
#     - fibroblasts
#
#   - standard Seurat workflow
#   - specific markers for each subgroup
#   - UMAP plots
#
# ## 50.5 CNV Analysis of Single Cells
#
#   - CNVs in tumor cell subgroups
#     - InferCNV
#     - references
#       - fibroblasts
#       - endothelial cells
#     - identify malignant cells within subgroups
#
# ## 50.6 Pseudotime Analysis of Single Cells
#
#   - Monocle2 software
#     - pseudotime analysis
#       - epithelial
#       - macrophage
#       - CAF cell
#
#   - DDRTree
#     - dimensionality reduction algorithm
#     - parameters set to default
#     - cell differentiation
#
# ## 50.7 Transcription Factor Analysis
#
#   - SCENIC software
#     - transcription factor analysis across cell subgroups
#     - default parameters
#       - RcisTarget
#       - GRNBoost motif databases
#
#   - RcisTarget package
#     - overexpressed transcription factor binding motifs
#
#   - AUCell package
#     - scored the activity of each regulatory module for each cell type
#
# ## 50.8 Cell-Cell Communication Analysis
#
#   - cell-cell communication
#     - CellChat package
#     - normalized gene expression matrix was imported
#
#   - Data preprocessing
#     - identifyOverExpressedGenes
#     - identifyOverExpressedInteraction
#     - ProjectData
#     - default parameters
#
#   - ligand-receptor interactions
#     - computeCommunProb
#     - filterCommunication
#     - computeCommunProbPathway
#
#   - cell communication network
#     - aggregateNet function
#
# ## 50.9 Statistical Analysis
#
#   - R 4.1.3
#     - data processing
#     - statistical analysis
#     - plotting
#
#   - Pearson correlation coefficient
#     - correlation between two continuous variables
#
#   - chi-square test
#     - categorical variables
#
#   - continuous variables
#     - Wilcoxon rank-sum test
#     - T-test
#
#   - survminer package
#     - determine optimal cutoff values
#
#   - survival package
#     - Cox regression
#     - Kaplan-Meier analyses

# %% [markdown]
# - “萧何”用户使用手册
#
#     - “分形”知识结构
#
#         - 模块化
#
#         - 自相似
#
#         - 分布与集成的辩证统一
#
#         - “郡县”与“分封”制度的优劣
#
#     - 认知负荷理论
#
#         - 最小记忆原理
#
#     - “刻意”
